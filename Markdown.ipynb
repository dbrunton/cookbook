# %% [markdown]
# # Markdown is a formatting dialect

# %% [markdown]
# It has some built-in formatting:
#
# # Big Headings
#
# and
#
# ## Subheadings
#
# and
#
# 1. numbered
# 2. lists
#
# and
#
# - bulleted
# - lists
#
# and
#
# __bold__ and *italic*
